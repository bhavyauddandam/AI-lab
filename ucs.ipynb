# %% [markdown]
# <a href="https://colab.research.google.com/github/bhavyauddandam/AI-lab/blob/main/ucs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import heapq


graph = {
    'A': [('B', 2), ('C', 1)],
    'B': [('D', 3)],
    'C': [],
    'D': [('E', 2)],
    'E': [('F', 4), ('H', 6)],
    'F': [('I', 1)],
    'H': [],
    'I': [('J', 2)],
    'J': []
}

def uniform_cost_search(start, goal):
    frontier = []
    heapq.heappush(frontier, (0, start, [start]))
    explored = set()
    level = 0

    while frontier:
        print("\n----------------------------")
        print("LEVEL:", level)
        print("Frontier:", frontier)
        print("Explored:", explored)

        cost, current, path = heapq.heappop(frontier)
        print("Expanding:", current, " Cost:", cost)

        if current == goal:
            print("\nGoal Found")
            print("Path:", path)
            print("Total Cost:", cost)
            return

        explored.add(current)

        for neighbor, weight in graph.get(current, []):
            if neighbor not in explored:
                heapq.heappush(frontier, (cost + weight, neighbor, path + [neighbor]))

        level += 1

    print("Goal not reachable")



start_node = 'A'
goal_node = 'J'
uniform_cost_search(start_node, goal_node)
# Out:
# ----------------------------
# LEVEL: 0
# Frontier: [(0, 'A', ['A'])]
# Explored: set()
# Expanding: A  Cost: 0
#
# ----------------------------
# LEVEL: 1
# Frontier: [(1, 'C', ['A', 'C']), (2, 'B', ['A', 'B'])]
# Explored: {'A'}
# Expanding: C  Cost: 1
#
# ----------------------------
# LEVEL: 2
# Frontier: [(2, 'B', ['A', 'B'])]
# Explored: {'A', 'C'}
# Expanding: B  Cost: 2
#
# ----------------------------
# LEVEL: 3
# Frontier: [(5, 'D', ['A', 'B', 'D'])]
# Explored: {'A', 'B', 'C'}
# Expanding: D  Cost: 5
#
# ----------------------------
# LEVEL: 4
# Frontier: [(7, 'E', ['A', 'B', 'D', 'E'])]
# Explored: {'A', 'B', 'D', 'C'}
# Expanding: E  Cost: 7
#
# ----------------------------
# LEVEL: 5
# Frontier: [(11, 'F', ['A', 'B', 'D', 'E', 'F']), (13, 'H', ['A', 'B', 'D', 'E', 'H'])]
# Explored: {'C', 'B', 'E', 'A', 'D'}
# Expanding: F  Cost: 11
#
# ----------------------------
# LEVEL: 6
# Frontier: [(12, 'I', ['A', 'B', 'D', 'E', 'F', 'I']), (13, 'H', ['A', 'B', 'D', 'E', 'H'])]
# Explored: {'F', 'C', 'B', 'E', 'A', 'D'}
# Expanding: I  Cost: 12
#
# ----------------------------
# LEVEL: 7
# Frontier: [(13, 'H', ['A', 'B', 'D', 'E', 'H']), (14, 'J', ['A', 'B', 'D', 'E', 'F', 'I', 'J'])]
# Explored: {'F', 'C', 'B', 'E', 'I', 'A', 'D'}
# Expanding: H  Cost: 13
#
# ----------------------------
# LEVEL: 8
# Frontier: [(14, 'J', ['A', 'B', 'D', 'E', 'F', 'I', 'J'])]
# Explored: {'F', 'C', 'B', 'E', 'H', 'I', 'A', 'D'}
# Expanding: J  Cost: 14
#
# Goal Found
# Path: ['A', 'B', 'D', 'E', 'F', 'I', 'J']
# Total Cost: 14
